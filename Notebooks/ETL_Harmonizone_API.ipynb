# %%
import os,requests,zlib
import pandas as pd
import numpy as np
from py2neo import Graph, NodeMatcher
from pprint import pprint

def _download_file(response, filename):
    with open(filename, 'wb') as f:
        for chunk in response.iter_content(chunk_size=1024):
            f.write(chunk)

def _download_and_decompress_file(response, filename):
    decompressor = zlib.decompressobj(16 + zlib.MAX_WBITS)
    filename = filename[:-3]
    with open(filename, 'w+') as f:
        while True:
            chunk = response.raw.read(1024)
            if not chunk:
                break
            string = decompressor.decompress(chunk).decode("latin-1") 
            f.write(string)

def download_datasets(selected_datasets, selected_downloads, decompress=False):
    for dataset, path in selected_datasets:
        if not os.path.exists(dataset):
            os.mkdir(dataset)
        for downloadable in selected_downloads:
            url = 'https://maayanlab.cloud/static/hdfs/harmonizome/data/%s/%s' %\
                  (path, downloadable)
            response = requests.get(url, stream=True)
            filename = '%s/%s' % (dataset, downloadable)
            # Not every dataset has all downloadables.
            if response.status_code != 200:
                continue
            if decompress and 'txt.gz' in filename:
                _download_and_decompress_file(response, filename)
            else:
                _download_file(response, filename)
        print('%s downloaded.' % dataset)

dwFiles = [
           'gene_attribute_edges.txt.gz',
           'gene_set_library_crisp.txt.gz',
           'gene_set_library_up_crisp.txt.gz',
           'gene_set_library_dn_crisp.txt.gz',
           'attribute_set_library_crisp.txt.gz',
           'attribute_set_library_up_crisp.txt.gz',
           'attribute_set_library_dn_crisp.txt.gz',
           'gene_list_terms.txt.gz',
           'attribute_list_entries.txt.gz']

# %%
# set up authenticated connection
#graph = GraphDatabase.driver("bolt://localhost:7687/PO2_Neo", auth=("neo4j", "ngs4"))
graph = Graph("bolt://localhost:7687/PublicOmics", auth=("neo4j", "ngs4"))

# %%
download_datasets([('Biocarta Pathways', 'biocarta')], dwFiles, decompress=True)
download_datasets([('HumanCyc Pathways', 'humancyc')], dwFiles, decompress=True)
download_datasets([('KEGG Pathways', 'kegg')], dwFiles, decompress=True)
# Out:
# Biocarta Pathways downloaded.

# %%
pathways = pd.read_csv('Biocarta Pathways/gene_attribute_edges.txt', sep='\t')
pathways = pathways.drop(["source_desc","target_desc"], axis=1)
pathways = pathways.iloc[1:]
pathways.head(3)
for row in pathways.itertuples():
    s2 = "MERGE (g:Gene { Symbol: '%s'}) SET g.EntrezId='%s' "%(row.source, row.source_id)
    s3 = "MERGE (p:Pathway { Name: '%s', Id: '%s', Origin: 'Biocarta'})"%(row.target,row.target_id)
    r1 = "MERGE (g)-[:BELONGS_TO{weight:%s}]->(p)"%(row.weight)
    subStmt = "{} {} {}".format(s2,s3,r1)
    graph.run(subStmt)
    
pathways = pd.read_csv('HumanCyc Pathways/gene_attribute_edges.txt', sep='\t')
pathways = pathways.drop(["target_id","target_desc"], axis=1)
pathways = pathways.iloc[1:]
pathways.head(3)
for row in pathways.itertuples():
    s2 = "MERGE (g:Gene { Symbol: '%s'}) SET g.EntrezId='%s', g.UniprotACC='%s' "%(row.source, row.source_id, row.source_desc)
    s3 = "MERGE (p:Pathway { Name: '%s', Origin: 'HumanCyc'})"%(row.target.replace('&','').replace(';','').replace("'",''))
    r1 = "MERGE (g)-[:BELONGS_TO{weight:%s}]->(p)"%(row.weight)
    subStmt = "{} {} {}".format(s2,s3,r1)
    graph.run(subStmt)
    
pathways = pd.read_csv('KEGG Pathways/gene_attribute_edges.txt', sep='\t')
pathways = pathways.drop(["source_desc","target_id"], axis=1)
pathways = pathways.iloc[1:]
pathways.head(3)
for row in pathways.itertuples():
    #pprint(row)  , : '%s'
    s2 = "MERGE (g:Gene {Symbol: '%s'}) SET g.EntrezId='%s'"%(row.source, row.source_id)
    s3 = "MERGE (p:Pathway {Name: '%s', Id: '%s', Origin:'Kegg'})"%(row.target,row.target_desc)
    r1 = "MERGE (g)-[:BELONGS_TO{weight:%s}]->(p)"%(row.weight)
    subStmt = "{} {} {}".format(s2,s3,r1)
    graph.run(subStmt)
# Out:
#       source source_id                          target target_id    weight
# 1       ADAR       103               antisense pathway    100241  1.000000
# 2       NONO      4841               antisense pathway    100241  1.000000
# 3       SFPQ      6421               antisense pathway    100241  1.000000
# 4      MATR3      9782               antisense pathway    100241  1.000000
# 5       AHSP     51327           hemoglobins chaperone    100250  1.000000
# ...      ...       ...                             ...       ...       ...
# 4505      C9       735  alternative complement pathway    100243  1.000000
# 4506     CFP      5199  alternative complement pathway    100243  1.000000
# 4507     CFD      1675  alternative complement pathway    100243  1.000000
# 4508    AGO2     27161                   dicer pathway    100188  1.000000
# 4509  DICER1     23405                   dicer pathway    100188  1.000000
#
# [4509 rows x 5 columns]

# %%
# ('OMIM Gene-Disease Associations', 'omim'),
download_datasets([('OMIM Gene-Disease Associations', 'omim')], dwFiles, decompress=True)
# ('GAD Gene-Disease Associations', 'gad'),
download_datasets([('GAD Gene-Disease Associations', 'gad')], dwFiles, decompress=True)
# ('DISEASES Curated Gene-Disease Assocation Evidence Scores', 'jensendiseasecurated'),
download_datasets([('DISEASES Curated Gene-Disease Assocation Evidence Scores', 'jensendiseasecurated')], dwFiles, decompress=True)
# Out:
# OMIM Gene-Disease Associations downloaded.
# GAD Gene-Disease Associations downloaded.
# DISEASES Curated Gene-Disease Assocation Evidence Scores downloaded.

# %%
disEntries = pd.read_csv('GAD Gene-Disease Associations/gene_attribute_edges.txt', sep='\t')
disEntries = disEntries.drop(["source_desc","target_id"], axis=1)
disEntries = disEntries.iloc[1:]
disEntries.head(3)
for row in disEntries.itertuples():
    for innerDis in row.target.split(';'):
        s1 = "MERGE (g:Gene {Symbol: '%s'}) SET g.EntrezId='%s'"%(row.source, row.source_id)
        s3 = "MERGE (p:Disease {Name: '%s', Origin:'GAD'})"%(innerDis.replace("'","\\'").strip())
        r1 = "MERGE (p)-[:ASSOCIATION_TO{weight:%s}]->(g)"%(row.weight)
        if row.target_desc != "unknown":
            s2 = "MERGE (c:DiseaseCategory {Name: '%s'})"%(row.target_desc)
            r2 = "MERGE (p)-[:CATEGORIZED_BY]->(c)"
            subStmt = "{} {} {} {} {}".format(s1,s2,s3,r1,r2)
        else:
            subStmt = "{} {} {}".format(s1,s3,r1)
        #print(subStmt+"\n")
        graph.run(subStmt)

# %%
# A question mark, "?", before the phenotype name indicates that the relationship between 
# the phenotype and gene is provisional. More details about this relationship are provided 
# in the comment field of the map and in the gene and phenotype OMIM entries.
disEntries = pd.read_csv('OMIM Gene-Disease Associations/gene_attribute_edges.txt', sep='\t')
#disEntries = disEntries.drop(["source_desc","target_id"], axis=1)
disEntries = disEntries.iloc[1:]
disEntries.head(3)
for row in disEntries.itertuples():
    cleanedDis = row.target.replace("'","\\'").replace("{","").replace("}","").replace("[","").replace("]","").strip()
    s1 = "MERGE (g:Gene {Symbol: '%s'}) SET g.EntrezId='%s' SET g.OmimId='%s'"%(row.source, row.source_id, row.source_desc.replace("OMIM:",""))
    if cleanedDis.startswith('?'):
        s3 = "MERGE (p:Disease {Name: '%s', Origin:'OMIM', PhenotypeClass: '%s'})"%(cleanedDis.replace('?',''), row.target_id)
        r1 = "MERGE (p)-[:PROVISIONAL{weight:%s}]->(g)"%(row.weight)
    else :
        s3 = "MERGE (p:Disease {Name: '%s', Origin:'OMIM', PhenotypeClass: '%s'})"%(cleanedDis, row.target_id)
        r1 = "MERGE (p)-[:ASSOCIATION_TO{weight:%s}]->(g)"%(row.weight)
    subStmt = "{} {} {}".format(s1,s3,r1)
    #print(subStmt+"\n")
    graph.run(subStmt)
# Out:
# MERGE (g:Gene {Symbol: 'CCR5'}) SET g.EntrezId='1234' SET g.OmimId='601373' MERGE (p:Disease {Name: 'hepatitis c virus, resistance to', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'CCR5'}) SET g.EntrezId='1234' SET g.OmimId='601373' MERGE (p:Disease {Name: 'west nile virus, susceptibility to', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'CCR5'}) SET g.EntrezId='1234' SET g.OmimId='601373' MERGE (p:Disease {Name: 'diabetes mellitus, insulin-dependent, 22', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'CCR2'}) SET g.EntrezId='729230' SET g.OmimId='601267' MERGE (p:Disease {Name: 'hiv infection, susceptibility/resistance to', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'CCR5'}) SET g.EntrezId='1234' SET g.OmimId='601373' MERGE (p:Disease {Name: 'hiv infection, susceptibility/resistance to', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'POU6F2'}) SET g.EntrezId='11281' SET g.OmimId='609062' MERGE (p:Disease {Name: 'wilms tumor susceptibility-5', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'DHTKD1'}) SET g.EntrezId='55526' SET g.OmimId='614984' MERGE (p:Disease {Name: '2-aminoadipic 2-oxoadipic aciduria', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'DHTKD1'}) SET g.EntrezId='55526' SET g.OmimId='614984' MERGE (p:Disease {Name: 'charcot-marie-tooth disease, axonal, type 2q', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'HSD3B2'}) SET g.EntrezId='3284' SET g.OmimId='613890' MERGE (p:Disease {Name: '3-beta-hydroxysteroid dehydrogenase, type ii, deficiency', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'HIBCH'}) SET g.EntrezId='26275' SET g.OmimId='610690' MERGE (p:Disease {Name: '3-hydroxyisobutryl-coa hydrolase deficiency', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'CUL7'}) SET g.EntrezId='9820' SET g.OmimId='609577' MERGE (p:Disease {Name: '3-m syndrome 1', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'OBSL1'}) SET g.EntrezId='23363' SET g.OmimId='610991' MERGE (p:Disease {Name: '3-m syndrome 2', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'CCDC8'}) SET g.EntrezId='83987' SET g.OmimId='614145' MERGE (p:Disease {Name: '3-m syndrome 3', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'MCCC1'}) SET g.EntrezId='56922' SET g.OmimId='609010' MERGE (p:Disease {Name: '3-methylcrotonyl-coa carboxylase 1 deficiency', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'MCCC2'}) SET g.EntrezId='64087' SET g.OmimId='609014' MERGE (p:Disease {Name: '3-methylcrotonyl-coa carboxylase 2 deficiency', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SERAC1'}) SET g.EntrezId='84947' SET g.OmimId='614725' MERGE (p:Disease {Name: '3-methylglutaconic aciduria with deafness, encephalopathy, and leigh-like syndrome', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'AUH'}) SET g.EntrezId='549' SET g.OmimId='600529' MERGE (p:Disease {Name: '3-methylglutaconic aciduria, type i', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'DNAJC19'}) SET g.EntrezId='131118' SET g.OmimId='608977' MERGE (p:Disease {Name: '3-methylglutaconic aciduria, type v', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'MASP1'}) SET g.EntrezId='5648' SET g.OmimId='600521' MERGE (p:Disease {Name: '3mc syndrome 1', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'COLEC11'}) SET g.EntrezId='78989' SET g.OmimId='612502' MERGE (p:Disease {Name: '3mc syndrome 2', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'DEL3PTERP25'}) SET g.EntrezId='100653385' SET g.OmimId='613792' MERGE (p:Disease {Name: '3p- syndrome', Origin:'OMIM', PhenotypeClass: '4'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'MECOM'}) SET g.EntrezId='2122' SET g.OmimId='165215' MERGE (p:Disease {Name: '3q21q26 syndrome', Origin:'OMIM', PhenotypeClass: '1'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SRXX2'}) SET g.EntrezId='100653378' SET g.OmimId='278850' MERGE (p:Disease {Name: '46xx sex reversal 2', Origin:'OMIM', PhenotypeClass: '4'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SRXX3'}) SET g.EntrezId='100653372' SET g.OmimId='300833' MERGE (p:Disease {Name: '46xx sex reversal 3', Origin:'OMIM', PhenotypeClass: '4'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SRY'}) SET g.EntrezId='6736' SET g.OmimId='480000' MERGE (p:Disease {Name: '46xx sex reversal 1', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SRY'}) SET g.EntrezId='6736' SET g.OmimId='480000' MERGE (p:Disease {Name: '46xy sex reversal 1', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'CBX2'}) SET g.EntrezId='84733' SET g.OmimId='602770' MERGE (p:Disease {Name: '46xy sex reversal 5', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'MAP3K1'}) SET g.EntrezId='4214' SET g.OmimId='600982' MERGE (p:Disease {Name: '46xy sex reversal 6', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'DHH'}) SET g.EntrezId='50846' SET g.OmimId='605423' MERGE (p:Disease {Name: '46xy partial gonadal dysgenesis, with minifascicular neuropathy', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'DHH'}) SET g.EntrezId='50846' SET g.OmimId='605423' MERGE (p:Disease {Name: '46xy sex reversal 7', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'OPLAH'}) SET g.EntrezId='26873' SET g.OmimId='614243' MERGE (p:Disease {Name: '5-oxoprolinase deficiency', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'TPMT'}) SET g.EntrezId='7172' SET g.OmimId='187680' MERGE (p:Disease {Name: '6-mercaptopurine sensitivity', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'NADK2'}) SET g.EntrezId='133686' SET g.OmimId='615787' MERGE (p:Disease {Name: '2,4-dienoyl-coa reductase deficiency', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'CD207'}) SET g.EntrezId='50489' SET g.OmimId='604862' MERGE (p:Disease {Name: 'birbeck granule deficiency', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'LIPE'}) SET g.EntrezId='3991' SET g.OmimId='151750' MERGE (p:Disease {Name: 'abdominal obesity-metabolic syndrome 4', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ACAT2'}) SET g.EntrezId='39' SET g.OmimId='100678' MERGE (p:Disease {Name: 'acat2 deficiency', Origin:'OMIM', PhenotypeClass: '1'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ANC'}) SET g.EntrezId='8066' SET g.OmimId='105580' MERGE (p:Disease {Name: 'anal canal carcinoma', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'STEAP3'}) SET g.EntrezId='55240' SET g.OmimId='609671' MERGE (p:Disease {Name: 'anemia, hypochromic microcytic, with iron overload 2', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'GLRX5'}) SET g.EntrezId='51218' SET g.OmimId='609588' MERGE (p:Disease {Name: 'anemia, sideroblastic, pyridoxine-refractory, autosomal recessive', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ELP4'}) SET g.EntrezId='26610' SET g.OmimId='606985' MERGE (p:Disease {Name: 'aniridia', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ATPLS'}) SET g.EntrezId='100499532' SET g.OmimId='107320' MERGE (p:Disease {Name: 'antiphospholipid syndrome, familial', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'BMS1'}) SET g.EntrezId='9790' SET g.OmimId='611448' MERGE (p:Disease {Name: 'aplasia cutis congenita, nonsyndromic', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SLC35A3'}) SET g.EntrezId='23443' SET g.OmimId='605632' MERGE (p:Disease {Name: 'arthrogryposis, mental retardation, and seizures', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'PCNA'}) SET g.EntrezId='5111' SET g.OmimId='176740' MERGE (p:Disease {Name: 'ataxia-telangiectasia-like disorder', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'NUP155'}) SET g.EntrezId='9631' SET g.OmimId='606694' MERGE (p:Disease {Name: 'atrial fibrillation 15', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'WDPCP'}) SET g.EntrezId='51057' SET g.OmimId='613580' MERGE (p:Disease {Name: 'bardet-biedl syndrome 15', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'BBIP1'}) SET g.EntrezId='92482' SET g.OmimId='613605' MERGE (p:Disease {Name: 'bardet-biedl syndrome 18', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'IFT27'}) SET g.EntrezId='11020' SET g.OmimId='615870' MERGE (p:Disease {Name: 'bardet-biedl syndrome 19', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'RASGRP2'}) SET g.EntrezId='10235' SET g.OmimId='605577' MERGE (p:Disease {Name: 'bleeding disorder, platelet-type, 18', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'PRKACG'}) SET g.EntrezId='5568' SET g.OmimId='176893' MERGE (p:Disease {Name: 'bleeding disorder, platelet-type, 19', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'BRCA3'}) SET g.EntrezId='60500' SET g.OmimId='605365' MERGE (p:Disease {Name: 'breast cancer, type 3', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'PTPRF'}) SET g.EntrezId='5792' SET g.OmimId='179590' MERGE (p:Disease {Name: 'breasts and/or nipples, aplasia or hypoplasia of, 2', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'TNNI3K'}) SET g.EntrezId='51086' SET g.OmimId='613932' MERGE (p:Disease {Name: 'cardiac conduction disease with or without dilated cardiomyopathy', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ACTN2'}) SET g.EntrezId='88' SET g.OmimId='102573' MERGE (p:Disease {Name: 'cardiomyopathy, dilated, 1aa', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'TMPO'}) SET g.EntrezId='7112' SET g.OmimId='188380' MERGE (p:Disease {Name: 'cardiomyopathy, dilated, 1t', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'CRAT'}) SET g.EntrezId='1384' SET g.OmimId='600184' MERGE (p:Disease {Name: 'carnitine acetyltransferase deficiency', Origin:'OMIM', PhenotypeClass: '1'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'CRYBA2'}) SET g.EntrezId='1412' SET g.OmimId='600836' MERGE (p:Disease {Name: 'cataract 42', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SORD'}) SET g.EntrezId='6652' SET g.OmimId='182500' MERGE (p:Disease {Name: 'cataract, congenital', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'IARS2'}) SET g.EntrezId='55699' SET g.OmimId='612801' MERGE (p:Disease {Name: 'cataracts, growth hormone deficiency, sensory neuropathy, sensorineural hearing loss, and skeletal dysplasia', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'TRIM2'}) SET g.EntrezId='23321' SET g.OmimId='614141' MERGE (p:Disease {Name: 'charcot-marie-tooth disease, type 2r', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SBF1'}) SET g.EntrezId='6305' SET g.OmimId='603560' MERGE (p:Disease {Name: 'charcot-marie-tooth disease, type 4b3', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'PDK3'}) SET g.EntrezId='5165' SET g.OmimId='300906' MERGE (p:Disease {Name: 'charcot-marie-tooth disease, x-linked dominant, 6', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SALL2'}) SET g.EntrezId='6297' SET g.OmimId='602219' MERGE (p:Disease {Name: 'coloboma, ocular, autosomal recessive', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'MRPL44'}) SET g.EntrezId='65080' SET g.OmimId='611849' MERGE (p:Disease {Name: 'combined oxidative phosphorylation deficiency 16', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'LYRM4'}) SET g.EntrezId='57128' SET g.OmimId='613311' MERGE (p:Disease {Name: 'combined oxidative phosphorylation deficiency 19', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'TARS2'}) SET g.EntrezId='80222' SET g.OmimId='612805' MERGE (p:Disease {Name: 'combined oxidative phosphorylation deficiency 21', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'DDOST'}) SET g.EntrezId='1650' SET g.OmimId='602202' MERGE (p:Disease {Name: 'congenital disorder of glycosylation, type ir', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'STT3A'}) SET g.EntrezId='3703' SET g.OmimId='601134' MERGE (p:Disease {Name: 'congenital disorder of glycosylation, type iw', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'STT3B'}) SET g.EntrezId='201595' SET g.OmimId='608605' MERGE (p:Disease {Name: 'congenital disorder of glycosylation, type ix', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SSR4'}) SET g.EntrezId='6748' SET g.OmimId='300090' MERGE (p:Disease {Name: 'congenital disorder of glycosylation, type iy', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'CFSS'}) SET g.EntrezId='100188773' SET g.OmimId='300712' MERGE (p:Disease {Name: 'craniofacioskeletal syndrome', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'CEACAM16'}) SET g.EntrezId='388551' SET g.OmimId='614591' MERGE (p:Disease {Name: 'deafness, autosomal dominant 4b', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'GRXCR2'}) SET g.EntrezId='643226' SET g.OmimId='615762' MERGE (p:Disease {Name: 'deafness, autosomal recessive 101', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'EPS8'}) SET g.EntrezId='2059' SET g.OmimId='600206' MERGE (p:Disease {Name: 'deafness, autosomal recessive 102', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'CLIC5'}) SET g.EntrezId='53405' SET g.OmimId='607293' MERGE (p:Disease {Name: 'deafness, autosomal recessive 103', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ADCY1'}) SET g.EntrezId='107' SET g.OmimId='103072' MERGE (p:Disease {Name: 'deafness, autosomal recessive 44', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ELMOD3'}) SET g.EntrezId='84173' SET g.OmimId='615427' MERGE (p:Disease {Name: 'deafness, autosomal recessive 88', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SERPINB6'}) SET g.EntrezId='5269' SET g.OmimId='173321' MERGE (p:Disease {Name: 'deafness, autosomal recessive 91', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'COL4A6'}) SET g.EntrezId='1288' SET g.OmimId='303631' MERGE (p:Disease {Name: 'deafness, x-linked 6', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'PBCA'}) SET g.EntrezId='7962' SET g.OmimId='600089' MERGE (p:Disease {Name: 'diabetes mellitus, insulin-dependent, neonatal', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'RPL26'}) SET g.EntrezId='6154' SET g.OmimId='603704' MERGE (p:Disease {Name: 'diamond-blackfan anemia 11', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'RPL15'}) SET g.EntrezId='6138' SET g.OmimId='604174' MERGE (p:Disease {Name: 'diamond-blackfan anemia 12', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'DGAT1'}) SET g.EntrezId='8694' SET g.OmimId='604900' MERGE (p:Disease {Name: 'diarrhea 7', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'CHRM3'}) SET g.EntrezId='1131' SET g.OmimId='118494' MERGE (p:Disease {Name: 'eagle-barrett syndrome', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'EEC1'}) SET g.EntrezId='1913' SET g.OmimId='129900' MERGE (p:Disease {Name: 'eec syndrome-1', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'DSE'}) SET g.EntrezId='29940' SET g.OmimId='605942' MERGE (p:Disease {Name: 'ehlers-danlos syndrome, musculocontractural type 2', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'CNTN2'}) SET g.EntrezId='6900' SET g.OmimId='190197' MERGE (p:Disease {Name: 'epilepsy, familial adult myoclonic, 5', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'NECAP1'}) SET g.EntrezId='25977' SET g.OmimId='611623' MERGE (p:Disease {Name: 'epileptic encephalopathy, early infantile, 21', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'EHHADH'}) SET g.EntrezId='1962' SET g.OmimId='607037' MERGE (p:Disease {Name: 'fanconi renotubular syndrome 3', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ALX1'}) SET g.EntrezId='8092' SET g.OmimId='601527' MERGE (p:Disease {Name: 'frontonasal dysplasia 3', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'DCAF8'}) SET g.EntrezId='50717' SET g.OmimId='615820' MERGE (p:Disease {Name: 'giant axonal neuropathy 2, autosomal dominant', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'GOPC'}) SET g.EntrezId='57120' SET g.OmimId='606845' MERGE (p:Disease {Name: 'globozoospermia', Origin:'OMIM', PhenotypeClass: '1'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ENO3'}) SET g.EntrezId='2027' SET g.OmimId='131370' MERGE (p:Disease {Name: 'glycogen storage disease xiii', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'GYG1'}) SET g.EntrezId='2992' SET g.OmimId='603942' MERGE (p:Disease {Name: 'glycogen storage disease xv', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ITGA2'}) SET g.EntrezId='3673' SET g.OmimId='192974' MERGE (p:Disease {Name: 'glycoprotein ia deficiency', Origin:'OMIM', PhenotypeClass: '1'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'HEY'}) SET g.EntrezId='100188776' SET g.OmimId='425500' MERGE (p:Disease {Name: 'hairy ears, y-linked', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'FTH1'}) SET g.EntrezId='2495' SET g.OmimId='134770' MERGE (p:Disease {Name: 'hemochromatosis, type 5', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'HTX3'}) SET g.EntrezId='116629' SET g.OmimId='606325' MERGE (p:Disease {Name: 'heterotaxy, visceral, 3, autosomal', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'KYNU'}) SET g.EntrezId='8942' SET g.OmimId='605197' MERGE (p:Disease {Name: 'hydroxykynureninuria', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'BCAT1'}) SET g.EntrezId='586' SET g.OmimId='113520' MERGE (p:Disease {Name: 'hyperleucinemia-isoleucinemia or hypervalinemia', Origin:'OMIM', PhenotypeClass: '1'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'PIGW'}) SET g.EntrezId='284098' SET g.OmimId='610275' MERGE (p:Disease {Name: 'hyperphosphatasia with mental retardation syndrome 5', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'NPR3'}) SET g.EntrezId='4883' SET g.OmimId='108962' MERGE (p:Disease {Name: 'hypertension, salt-resistant', Origin:'OMIM', PhenotypeClass: '1'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'HTC1'}) SET g.EntrezId='3341' SET g.OmimId='145701' MERGE (p:Disease {Name: 'hypertrichosis universalis congenita, ambras type', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'BCAT2'}) SET g.EntrezId='587' SET g.OmimId='113530' MERGE (p:Disease {Name: 'hypervalinemia or hyperleucine-isoleucinemia', Origin:'OMIM', PhenotypeClass: '1'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'GNRH1'}) SET g.EntrezId='2796' SET g.OmimId='152760' MERGE (p:Disease {Name: 'hypogonadotropic hypogonadism 12 with or without anosmia', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'KISS1'}) SET g.EntrezId='3814' SET g.OmimId='603286' MERGE (p:Disease {Name: 'hypogonadotropic hypogonadism 13 with or without anosmia', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'KRT71'}) SET g.EntrezId='112802' SET g.OmimId='608245' MERGE (p:Disease {Name: 'hypotrichosis 13', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'DSC3'}) SET g.EntrezId='1825' SET g.OmimId='600271' MERGE (p:Disease {Name: 'hypotrichosis and recurrent skin vesicles', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'UNC119'}) SET g.EntrezId='9094' SET g.OmimId='604011' MERGE (p:Disease {Name: 'cone-rod dystrophy', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'UNC119'}) SET g.EntrezId='9094' SET g.OmimId='604011' MERGE (p:Disease {Name: 'immunodeficiency 13', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'TNFRSF4'}) SET g.EntrezId='7293' SET g.OmimId='600315' MERGE (p:Disease {Name: 'immunodeficiency 16', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'LCK'}) SET g.EntrezId='3932' SET g.OmimId='153390' MERGE (p:Disease {Name: 'immunodeficiency 22', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'CD247'}) SET g.EntrezId='919' SET g.OmimId='186780' MERGE (p:Disease {Name: 'immunodeficiency 25', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'IL21'}) SET g.EntrezId='59067' SET g.OmimId='605384' MERGE (p:Disease {Name: 'immunodeficiency, common variable, 11', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'HNRNPA2B1'}) SET g.EntrezId='3181' SET g.OmimId='600124' MERGE (p:Disease {Name: 'inclusion body myopathy with early-onset paget disease with or without frontotemporal dementia 2', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'LARS'}) SET g.EntrezId='51520' SET g.OmimId='151350' MERGE (p:Disease {Name: 'infantile liver failure syndrome 1', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'MARS'}) SET g.EntrezId='4141' SET g.OmimId='156560' MERGE (p:Disease {Name: 'infantile liver failure syndrome 2', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ADAM17'}) SET g.EntrezId='6868' SET g.OmimId='603639' MERGE (p:Disease {Name: 'inflammatory skin and bowel disease, neonatal, 1', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'PDE6D'}) SET g.EntrezId='5147' SET g.OmimId='602676' MERGE (p:Disease {Name: 'joubert syndrome 22', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'LAP'}) SET g.EntrezId='7939' SET g.OmimId='150270' MERGE (p:Disease {Name: 'laryngeal adductor paralysis', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'CIDEC'}) SET g.EntrezId='63924' SET g.OmimId='612120' MERGE (p:Disease {Name: 'lipodystrophy, familial partial, type 5', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ACP2'}) SET g.EntrezId='53' SET g.OmimId='171650' MERGE (p:Disease {Name: 'lysosomal acid phosphatase deficiency', Origin:'OMIM', PhenotypeClass: '1'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'UBE2B'}) SET g.EntrezId='7320' SET g.OmimId='179095' MERGE (p:Disease {Name: 'male infertility', Origin:'OMIM', PhenotypeClass: '1'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ACR'}) SET g.EntrezId='49' SET g.OmimId='102480' MERGE (p:Disease {Name: 'male infertility due to acrosin deficiency', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'MROS'}) SET g.EntrezId='8011' SET g.OmimId='155900' MERGE (p:Disease {Name: 'melkersson-rosenthal syndrome', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'EPB41L1'}) SET g.EntrezId='2036' SET g.OmimId='602879' MERGE (p:Disease {Name: 'mental retardation, autosomal dominant 11', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ZBTB18'}) SET g.EntrezId='10472' SET g.OmimId='608433' MERGE (p:Disease {Name: 'mental retardation, autosomal dominant 22', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'PGAP1'}) SET g.EntrezId='80055' SET g.OmimId='611655' MERGE (p:Disease {Name: 'mental retardation, autosomal recessive 42', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'KIAA1033'}) SET g.EntrezId='23325' SET g.OmimId='615748' MERGE (p:Disease {Name: 'mental retardation, autosomal recessive 43', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'FBXO31'}) SET g.EntrezId='79791' SET g.OmimId='609102' MERGE (p:Disease {Name: 'mental retardation, autosomal recessive 45', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ANK3'}) SET g.EntrezId='288' SET g.OmimId='600465' MERGE (p:Disease {Name: 'mental retardation, autosomal recessive, 37', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'KIF4A'}) SET g.EntrezId='24137' SET g.OmimId='300521' MERGE (p:Disease {Name: 'mental retardation, x-linked 100', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'MID2'}) SET g.EntrezId='11043' SET g.OmimId='300204' MERGE (p:Disease {Name: 'mental retardation, x-linked 101', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ZDHHC15'}) SET g.EntrezId='158866' SET g.OmimId='300576' MERGE (p:Disease {Name: 'mental retardation, x-linked 91', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'MRXS12'}) SET g.EntrezId='8246' SET g.OmimId='309545' MERGE (p:Disease {Name: 'mental retardation, x-linked, syndromic 12', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ZNF335'}) SET g.EntrezId='63925' SET g.OmimId='610827' MERGE (p:Disease {Name: 'microcephaly 10, primary, autosomal recessive', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'PHC1'}) SET g.EntrezId='1911' SET g.OmimId='602978' MERGE (p:Disease {Name: 'microcephaly 11, primary, autosomal recessive', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'CDK6'}) SET g.EntrezId='1021' SET g.OmimId='603368' MERGE (p:Disease {Name: 'microcephaly 12, primary, autosomal recessive', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'CENPE'}) SET g.EntrezId='1062' SET g.OmimId='117143' MERGE (p:Disease {Name: 'microcephaly 13, primary, autosomal recessive', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'CEP135'}) SET g.EntrezId='9662' SET g.OmimId='611423' MERGE (p:Disease {Name: 'microcephaly 8, primary, autosomal recessive', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'HMGB3'}) SET g.EntrezId='3149' SET g.OmimId='300193' MERGE (p:Disease {Name: 'microphthalmia, syndromic 13', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'HOXA2'}) SET g.EntrezId='3199' SET g.OmimId='604685' MERGE (p:Disease {Name: 'microtia with or without hearing impairment (ad)', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'HOXA2'}) SET g.EntrezId='3199' SET g.OmimId='604685' MERGE (p:Disease {Name: 'microtia, hearing impairment, and cleft palate (ar)', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'DNAL4'}) SET g.EntrezId='10126' SET g.OmimId='610565' MERGE (p:Disease {Name: 'mirror movements 3', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ATP5A1'}) SET g.EntrezId='498' SET g.OmimId='164360' MERGE (p:Disease {Name: 'combined oxidative phosphorylation deficiency 22', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ATP5A1'}) SET g.EntrezId='498' SET g.OmimId='164360' MERGE (p:Disease {Name: 'mitochondrial complex (atp synthase) deficiency, nuclear type 4', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'NDUFB9'}) SET g.EntrezId='4715' SET g.OmimId='601445' MERGE (p:Disease {Name: 'mitochondrial complex i deficiency', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'TTC19'}) SET g.EntrezId='54902' SET g.OmimId='613814' MERGE (p:Disease {Name: 'mitochondrial complex iii deficiency, nuclear type 2', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'UQCC2'}) SET g.EntrezId='84300' SET g.OmimId='614461' MERGE (p:Disease {Name: 'mitochondrial complex iii deficiency, nuclear type 7', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'LYRM7'}) SET g.EntrezId='90624' SET g.OmimId='615831' MERGE (p:Disease {Name: 'mitochondrial complex iii deficiency, nuclear type 8', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'UQCC3'}) SET g.EntrezId='790955' SET g.OmimId='616097' MERGE (p:Disease {Name: 'mitochondrial complex iii deficiency, nuclear type 9', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'COX14'}) SET g.EntrezId='84987' SET g.OmimId='614478' MERGE (p:Disease {Name: 'mitochondrial complex iv deficiency', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'FASTKD2'}) SET g.EntrezId='22868' SET g.OmimId='612322' MERGE (p:Disease {Name: 'mitochondrial complex iv deficiency', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'TACO1'}) SET g.EntrezId='51204' SET g.OmimId='612958' MERGE (p:Disease {Name: 'mitochondrial complex iv deficiency', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'COX6B1'}) SET g.EntrezId='1340' SET g.OmimId='124089' MERGE (p:Disease {Name: 'mitochondrial complex iv deficiency', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ATP5E'}) SET g.EntrezId='514' SET g.OmimId='606153' MERGE (p:Disease {Name: 'mitochondrial complex v (atp synthase) deficiency, nuclear type 3', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'KRT83'}) SET g.EntrezId='3889' SET g.OmimId='602765' MERGE (p:Disease {Name: 'monilethrix', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'IBA57'}) SET g.EntrezId='200205' SET g.OmimId='615316' MERGE (p:Disease {Name: 'multiple mitochondrial dysfunctions syndrome 3', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'FGF9'}) SET g.EntrezId='2254' SET g.OmimId='600921' MERGE (p:Disease {Name: 'multiple synostoses syndrome 3', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'CNTN1'}) SET g.EntrezId='1272' SET g.OmimId='600016' MERGE (p:Disease {Name: 'myopathy, congenital, compton-north', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ORAI1'}) SET g.EntrezId='84876' SET g.OmimId='610277' MERGE (p:Disease {Name: 'immunodeficiency 9', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ORAI1'}) SET g.EntrezId='84876' SET g.OmimId='610277' MERGE (p:Disease {Name: 'myopathy, tubular aggregate, 2', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'POLA1'}) SET g.EntrezId='5422' SET g.OmimId='312040' MERGE (p:Disease {Name: 'n syndrome', Origin:'OMIM', PhenotypeClass: '1'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'NAT8L'}) SET g.EntrezId='339983' SET g.OmimId='610647' MERGE (p:Disease {Name: 'n-acetylaspartate deficiency', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'TMEM98'}) SET g.EntrezId='26022' SET g.OmimId='615949' MERGE (p:Disease {Name: 'nanophthalmos 4', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'TP73'}) SET g.EntrezId='7161' SET g.OmimId='601990' MERGE (p:Disease {Name: 'neuroblastoma', Origin:'OMIM', PhenotypeClass: '1'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'HSPB3'}) SET g.EntrezId='8988' SET g.OmimId='604624' MERGE (p:Disease {Name: 'neuronopathy, distal hereditary motor, type iic', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'NM'}) SET g.EntrezId='4827' SET g.OmimId='162820' MERGE (p:Disease {Name: 'neutrophil chemotactic repsonse, abnormal', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'CSF3R'}) SET g.EntrezId='1441' SET g.OmimId='138971' MERGE (p:Disease {Name: 'neutrophilia, hereditary', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'NTRK2'}) SET g.EntrezId='4915' SET g.OmimId='600456' MERGE (p:Disease {Name: 'obesity, hyperphagia, and developmental delay', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'C2CD3'}) SET g.EntrezId='26005' SET g.OmimId='615944' MERGE (p:Disease {Name: 'orofaciodigital syndrome xiv', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'PAX1'}) SET g.EntrezId='5075' SET g.OmimId='167411' MERGE (p:Disease {Name: 'otofaciocervical syndrome 2', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ST11'}) SET g.EntrezId='8466' SET g.OmimId='602011' MERGE (p:Disease {Name: 'pancreatic endocrine tumors', Origin:'OMIM', PhenotypeClass: '1'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ATP6AP2'}) SET g.EntrezId='10159' SET g.OmimId='300556' MERGE (p:Disease {Name: 'mental retardation, x-linked, syndromic, hedera type', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ATP6AP2'}) SET g.EntrezId='10159' SET g.OmimId='300556' MERGE (p:Disease {Name: 'parkinsonism with spasticity, x-linked', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'PIGT'}) SET g.EntrezId='51604' SET g.OmimId='610272' MERGE (p:Disease {Name: 'multiple congenital anomalies-hypotonia-seizures syndrome 3', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'PIGT'}) SET g.EntrezId='51604' SET g.OmimId='610272' MERGE (p:Disease {Name: 'paroxysmal nocturnal hemoglobinuria 2', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ERMARD'}) SET g.EntrezId='55780' SET g.OmimId='615532' MERGE (p:Disease {Name: 'periventricular nodular heterotopia 6', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'PCK1'}) SET g.EntrezId='5105' SET g.OmimId='614168' MERGE (p:Disease {Name: 'phosphoenolpyruvate carboxykinase-1, cytosolic, deficiency', Origin:'OMIM', PhenotypeClass: '1'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ZNF141'}) SET g.EntrezId='7700' SET g.OmimId='194648' MERGE (p:Disease {Name: 'polydactyly, postaxial, type a6', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'DMXL2'}) SET g.EntrezId='23312' SET g.OmimId='612186' MERGE (p:Disease {Name: 'polyendocrine-polyneuropathy syndrome', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'PAFC'}) SET g.EntrezId='404715' SET g.OmimId='128700' MERGE (p:Disease {Name: 'preauricular fistulae, congenital', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'STAG3'}) SET g.EntrezId='10734' SET g.OmimId='608489' MERGE (p:Disease {Name: 'premature ovarian failure 8', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'KCNJ8'}) SET g.EntrezId='3764' SET g.OmimId='600935' MERGE (p:Disease {Name: 'prinzmetal angina', Origin:'OMIM', PhenotypeClass: '1'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'PGR'}) SET g.EntrezId='5241' SET g.OmimId='607311' MERGE (p:Disease {Name: 'progesterone resistance', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ZFHX4'}) SET g.EntrezId='79776' SET g.OmimId='606940' MERGE (p:Disease {Name: 'ptosis, congenital', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'RWS'}) SET g.EntrezId='7937' SET g.OmimId='179450' MERGE (p:Disease {Name: 'ragweed sensitivity', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'FGF20'}) SET g.EntrezId='26281' SET g.OmimId='605558' MERGE (p:Disease {Name: 'renal hypodysplasia/aplasia 2', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'NEK8'}) SET g.EntrezId='284086' SET g.OmimId='609799' MERGE (p:Disease {Name: 'nephronophthisis 9', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'NEK8'}) SET g.EntrezId='284086' SET g.OmimId='609799' MERGE (p:Disease {Name: 'renal-hepatic-pancreatic dysplasia 2', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'RCD1'}) SET g.EntrezId='5953' SET g.OmimId='180020' MERGE (p:Disease {Name: 'retinal cone dystrophy-1', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'RDH11'}) SET g.EntrezId='51109' SET g.OmimId='607849' MERGE (p:Disease {Name: 'retinal dystrophy, juvenile cataracts, and short stature syndrome', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'RBP3'}) SET g.EntrezId='5949' SET g.OmimId='180290' MERGE (p:Disease {Name: 'retinitis pigmentosa 66', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'NEK2'}) SET g.EntrezId='4751' SET g.OmimId='604043' MERGE (p:Disease {Name: 'retinitis pigmentosa 67', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'RP9'}) SET g.EntrezId='6100' SET g.OmimId='607331' MERGE (p:Disease {Name: 'retinitis pigmentosa 9', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'RP6'}) SET g.EntrezId='6104' SET g.OmimId='312612' MERGE (p:Disease {Name: 'retinitis pigmentosa, x-linked recessive, 6', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'RCHTS'}) SET g.EntrezId='100462676' SET g.OmimId='613328' MERGE (p:Disease {Name: 'roifman-chitayat syndrome', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SRPX2'}) SET g.EntrezId='27286' SET g.OmimId='300642' MERGE (p:Disease {Name: 'rolandic epilepsy, mental retardation, and speech dyspraxia', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SSX1'}) SET g.EntrezId='6756' SET g.OmimId='312820' MERGE (p:Disease {Name: 'sarcoma, synovial', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SSX2'}) SET g.EntrezId='6757' SET g.OmimId='300192' MERGE (p:Disease {Name: 'sarcoma, synovial', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'CEP63'}) SET g.EntrezId='80254' SET g.OmimId='614724' MERGE (p:Disease {Name: 'seckel syndrome 6', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'DAZ1'}) SET g.EntrezId='1617' SET g.OmimId='400003' MERGE (p:Disease {Name: 'sertoli-cell-only syndrome', Origin:'OMIM', PhenotypeClass: '1'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ARHGEF10'}) SET g.EntrezId='9639' SET g.OmimId='608136' MERGE (p:Disease {Name: 'slowed nerve conduction velocity, ad', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SPG41'}) SET g.EntrezId='100359402' SET g.OmimId='613364' MERGE (p:Disease {Name: 'spastic paraplegia 41, autosomal dominant', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ARL6IP1'}) SET g.EntrezId='23204' SET g.OmimId='607669' MERGE (p:Disease {Name: 'spastic paraplegia 61, autosomal recessive', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'REEP2'}) SET g.EntrezId='51308' SET g.OmimId='609347' MERGE (p:Disease {Name: 'spastic paraplegia 72, autosomal dominant', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'REEP2'}) SET g.EntrezId='51308' SET g.OmimId='609347' MERGE (p:Disease {Name: 'spastic paraplegia 72, autosomal recessive', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'TAF4B'}) SET g.EntrezId='6875' SET g.OmimId='601689' MERGE (p:Disease {Name: 'spermatogenic failure 13', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ZMYND15'}) SET g.EntrezId='84225' SET g.OmimId='614312' MERGE (p:Disease {Name: 'spermatogenic failure 14', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'EEF2'}) SET g.EntrezId='1938' SET g.OmimId='130610' MERGE (p:Disease {Name: 'spinocerebellar ataxia 26', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SCA30'}) SET g.EntrezId='100359393' SET g.OmimId='613371' MERGE (p:Disease {Name: 'spinocerebellar ataxia 30', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'KIAA0226'}) SET g.EntrezId='9711' SET g.OmimId='613516' MERGE (p:Disease {Name: 'spinocerebellar ataxia, autosomal recessive 15', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:PROVISIONAL{weight:1.000000}]->(g)
#
# ...
#
# MERGE (g:Gene {Symbol: 'CDH1'}) SET g.EntrezId='999' SET g.OmimId='192090' MERGE (p:Disease {Name: 'breast cancer, lobular', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'RCBTB1'}) SET g.EntrezId='55213' SET g.OmimId='607867' MERGE (p:Disease {Name: 'beta-glycopyranoside tasting', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'GABRA2'}) SET g.EntrezId='2555' SET g.OmimId='137140' MERGE (p:Disease {Name: 'alcohol dependence, susceptibility to', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'RCBTB1'}) SET g.EntrezId='55213' SET g.OmimId='607867' MERGE (p:Disease {Name: 'alcohol dependence, susceptibility to', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'HTR2A'}) SET g.EntrezId='3356' SET g.OmimId='182135' MERGE (p:Disease {Name: 'alcohol dependence, susceptibility to', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'HTR2A'}) SET g.EntrezId='3356' SET g.OmimId='182135' MERGE (p:Disease {Name: 'anorexia nervosa, susceptibility to', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'BDNF'}) SET g.EntrezId='627' SET g.OmimId='113505' MERGE (p:Disease {Name: 'anorexia nervosa, susceptibility to', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'HTR2A'}) SET g.EntrezId='3356' SET g.OmimId='182135' MERGE (p:Disease {Name: 'major depressive disorder, response to citalopram therapy in', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'HTR2A'}) SET g.EntrezId='3356' SET g.OmimId='182135' MERGE (p:Disease {Name: 'obsessive-compulsive disorder, susceptibility to', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'HTR2A'}) SET g.EntrezId='3356' SET g.OmimId='182135' MERGE (p:Disease {Name: 'seasonal affective disorder, susceptibility to', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ASCL1'}) SET g.EntrezId='429' SET g.OmimId='100790' MERGE (p:Disease {Name: 'central hypoventilation syndrome, congenital', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'EDN3'}) SET g.EntrezId='1908' SET g.OmimId='131242' MERGE (p:Disease {Name: 'central hypoventilation syndrome, congenital', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'BDNF'}) SET g.EntrezId='627' SET g.OmimId='113505' MERGE (p:Disease {Name: 'central hypoventilation syndrome, congenital', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'RET'}) SET g.EntrezId='5979' SET g.OmimId='164761' MERGE (p:Disease {Name: 'central hypoventilation syndrome, congenital', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'BDNF'}) SET g.EntrezId='627' SET g.OmimId='113505' MERGE (p:Disease {Name: 'bulimia nervosa, age of onset of weight loss in', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'BDNF'}) SET g.EntrezId='627' SET g.OmimId='113505' MERGE (p:Disease {Name: 'memory impairment, susceptibility to', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'BDNF'}) SET g.EntrezId='627' SET g.OmimId='113505' MERGE (p:Disease {Name: 'obsessive-compulsive disorder, protection against', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'EDN3'}) SET g.EntrezId='1908' SET g.OmimId='131242' MERGE (p:Disease {Name: 'waardenburg syndrome, type 4b', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'EDN3'}) SET g.EntrezId='1908' SET g.OmimId='131242' MERGE (p:Disease {Name: 'hirschsprung disease, susceptibility to, 4', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'ASCL1'}) SET g.EntrezId='429' SET g.OmimId='100790' MERGE (p:Disease {Name: 'haddad syndrome', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'MTHFR'}) SET g.EntrezId='4524' SET g.OmimId='607093' MERGE (p:Disease {Name: 'homocystinuria due to mthfr deficiency', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'MTHFR'}) SET g.EntrezId='4524' SET g.OmimId='607093' MERGE (p:Disease {Name: 'thromboembolism, susceptibility to', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'MTHFR'}) SET g.EntrezId='4524' SET g.OmimId='607093' MERGE (p:Disease {Name: 'vascular disease, susceptibility to', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'MTHFR'}) SET g.EntrezId='4524' SET g.OmimId='607093' MERGE (p:Disease {Name: 'neural tube defects, susceptibility to', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'T'}) SET g.EntrezId='6862' SET g.OmimId='601397' MERGE (p:Disease {Name: 'neural tube defects, susceptibility to', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'T'}) SET g.EntrezId='6862' SET g.OmimId='601397' MERGE (p:Disease {Name: 'sacral agenesis with vertebral anomalies', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'CHI3L1'}) SET g.EntrezId='1116' SET g.OmimId='601525' MERGE (p:Disease {Name: 'asthma-related traits, susceptibility to, 7', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'DRD3'}) SET g.EntrezId='1814' SET g.OmimId='126451' MERGE (p:Disease {Name: 'essential tremor, susceptibility to', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'COMT'}) SET g.EntrezId='1312' SET g.OmimId='116790' MERGE (p:Disease {Name: 'panic disorder, susceptibility to', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'DISC1'}) SET g.EntrezId='27185' SET g.OmimId='605210' MERGE (p:Disease {Name: 'schizoaffective disorder, susceptibility to', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'AKT1'}) SET g.EntrezId='207' SET g.OmimId='164730' MERGE (p:Disease {Name: 'schizophrenia, susceptibility to', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'CHI3L1'}) SET g.EntrezId='1116' SET g.OmimId='601525' MERGE (p:Disease {Name: 'schizophrenia, susceptibility to', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'COMT'}) SET g.EntrezId='1312' SET g.OmimId='116790' MERGE (p:Disease {Name: 'schizophrenia, susceptibility to', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'DISC1'}) SET g.EntrezId='27185' SET g.OmimId='605210' MERGE (p:Disease {Name: 'schizophrenia, susceptibility to', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'DRD3'}) SET g.EntrezId='1814' SET g.OmimId='126451' MERGE (p:Disease {Name: 'schizophrenia, susceptibility to', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'RTN4R'}) SET g.EntrezId='65078' SET g.OmimId='605566' MERGE (p:Disease {Name: 'schizophrenia, susceptibility to', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SYN2'}) SET g.EntrezId='6854' SET g.OmimId='600755' MERGE (p:Disease {Name: 'schizophrenia, susceptibility to', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'MTHFR'}) SET g.EntrezId='4524' SET g.OmimId='607093' MERGE (p:Disease {Name: 'schizophrenia, susceptibility to', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'HTR2A'}) SET g.EntrezId='3356' SET g.OmimId='182135' MERGE (p:Disease {Name: 'schizophrenia, susceptibility to', Origin:'OMIM', PhenotypeClass: '2'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SDHD'}) SET g.EntrezId='6392' SET g.OmimId='602690' MERGE (p:Disease {Name: 'carcinoid tumors, intestinal', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SDHD'}) SET g.EntrezId='6392' SET g.OmimId='602690' MERGE (p:Disease {Name: 'merkel cell carcinoma, somatic', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SDHD'}) SET g.EntrezId='6392' SET g.OmimId='602690' MERGE (p:Disease {Name: 'paragangliomas 1, with or without deafness', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SDHD'}) SET g.EntrezId='6392' SET g.OmimId='602690' MERGE (p:Disease {Name: 'cowden syndrome 3', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SDHB'}) SET g.EntrezId='6390' SET g.OmimId='185470' MERGE (p:Disease {Name: 'cowden syndrome 2', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SDHB'}) SET g.EntrezId='6390' SET g.OmimId='185470' MERGE (p:Disease {Name: 'paragangliomas 4', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SDHB'}) SET g.EntrezId='6390' SET g.OmimId='185470' MERGE (p:Disease {Name: 'gastrointestinal stromal tumor', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SDHC'}) SET g.EntrezId='6391' SET g.OmimId='602413' MERGE (p:Disease {Name: 'gastrointestinal stromal tumor', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SDHB'}) SET g.EntrezId='6390' SET g.OmimId='185470' MERGE (p:Disease {Name: 'paraganglioma and gastric stromal sarcoma', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SDHC'}) SET g.EntrezId='6391' SET g.OmimId='602413' MERGE (p:Disease {Name: 'paraganglioma and gastric stromal sarcoma', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SDHD'}) SET g.EntrezId='6392' SET g.OmimId='602690' MERGE (p:Disease {Name: 'paraganglioma and gastric stromal sarcoma', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SDHC'}) SET g.EntrezId='6391' SET g.OmimId='602413' MERGE (p:Disease {Name: 'paragangliomas 3', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'KIF1B'}) SET g.EntrezId='23095' SET g.OmimId='605995' MERGE (p:Disease {Name: 'charcot-marie-tooth disease, type 2a1', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'KIF1B'}) SET g.EntrezId='23095' SET g.OmimId='605995' MERGE (p:Disease {Name: 'neuroblastoma, susceptibility to, 1', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'RET'}) SET g.EntrezId='5979' SET g.OmimId='164761' MERGE (p:Disease {Name: 'pheochromocytoma', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'KIF1B'}) SET g.EntrezId='23095' SET g.OmimId='605995' MERGE (p:Disease {Name: 'pheochromocytoma', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'VHL'}) SET g.EntrezId='7428' SET g.OmimId='608537' MERGE (p:Disease {Name: 'pheochromocytoma', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SDHB'}) SET g.EntrezId='6390' SET g.OmimId='185470' MERGE (p:Disease {Name: 'pheochromocytoma', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'SDHD'}) SET g.EntrezId='6392' SET g.OmimId='602690' MERGE (p:Disease {Name: 'pheochromocytoma', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'RET'}) SET g.EntrezId='5979' SET g.OmimId='164761' MERGE (p:Disease {Name: 'medullary thyroid carcinoma', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'RET'}) SET g.EntrezId='5979' SET g.OmimId='164761' MERGE (p:Disease {Name: 'renal agenesis', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'RET'}) SET g.EntrezId='5979' SET g.OmimId='164761' MERGE (p:Disease {Name: 'hirschsprung disease, susceptibility to, 1', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'RET'}) SET g.EntrezId='5979' SET g.OmimId='164761' MERGE (p:Disease {Name: 'multiple endocrine neoplasia iia', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'RET'}) SET g.EntrezId='5979' SET g.OmimId='164761' MERGE (p:Disease {Name: 'multiple endocrine neoplasia iib', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'VHL'}) SET g.EntrezId='7428' SET g.OmimId='608537' MERGE (p:Disease {Name: 'erythrocytosis, familial, 2', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'VHL'}) SET g.EntrezId='7428' SET g.OmimId='608537' MERGE (p:Disease {Name: 'renal cell carcinoma, somatic', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'VHL'}) SET g.EntrezId='7428' SET g.OmimId='608537' MERGE (p:Disease {Name: 'von hippel-lindau syndrome', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'VHL'}) SET g.EntrezId='7428' SET g.OmimId='608537' MERGE (p:Disease {Name: 'hemangioblastoma, cerebellar, somatic', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'F9'}) SET g.EntrezId='2158' SET g.OmimId='300746' MERGE (p:Disease {Name: 'hemophilia b', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'F9'}) SET g.EntrezId='2158' SET g.OmimId='300746' MERGE (p:Disease {Name: 'deep venous thrombosis, protection against', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'F9'}) SET g.EntrezId='2158' SET g.OmimId='300746' MERGE (p:Disease {Name: 'warfarin sensitivity', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)
#
# MERGE (g:Gene {Symbol: 'F9'}) SET g.EntrezId='2158' SET g.OmimId='300746' MERGE (p:Disease {Name: 'thrombophilia, x-linked, due to factor ix defect', Origin:'OMIM', PhenotypeClass: '3'}) MERGE (p)-[:ASSOCIATION_TO{weight:1.000000}]->(g)

# %%
disEntries = pd.read_csv('DISEASES Curated Gene-Disease Assocation Evidence Scores/gene_attribute_edges.txt', sep='\t')
#disEntries = disEntries.drop(["source_desc","target_id"], axis=1)
disEntries = disEntries.iloc[1:]
disEntries

for row in pathways.itertuples():
    #pprint(row)  , : '%s'
    s2 = "MERGE (g:Gene {Symbol: '%s'}) SET g.EntrezId='%s' SET g.EnsembleId='%s'"%(row.source, row.source_id, row.source_desc)
    s3 = "MERGE (p:Disease {Name: '%s', Id: '%s', Origin:'JensenDiseaseCurated'})"%(row.target,row.target_desc)
    r1 = "MERGE (g)-[:BELONGS_TO{weight:%s}]->(p)"%(row.weight)
    subStmt = "{} {} {}".format(s2,s3,r1)
    graph.run(subStmt)
# Out:
#          source      source_desc source_id                             target  \
# 1           VHL  ENSP00000256474      7428                   hemangioblastoma
# 2           VHL  ENSP00000256474      7428          von hippel-lindau disease
# 3           VHL  ENSP00000256474      7428                         hemangioma
# 4           VHL  ENSP00000256474      7428          cell type benign neoplasm
# 5           VHL  ENSP00000256474      7428                    benign neoplasm
# ...         ...              ...       ...                                ...
# 18140     ABCC2  ENSP00000359478      1244             dubin-johnson syndrome
# 18141    UGT1A1  ENSP00000304845     54658            crigler-najjar syndrome
# 18142    UGT1A1  ENSP00000304845     54658                   gilbert syndrome
# 18143  SERPINA1  ENSP00000348068      5265     alpha 1-antitrypsin deficiency
# 18144  SERPINA1  ENSP00000348068      5265  plasma protein metabolism disease
#
#         target_desc  target_id    weight
# 1         DOID:5241     -666.0  1.000000
# 2        DOID:14175     -666.0  1.000000
# 3          DOID:255     -666.0  1.000000
# 4      DOID:0060084     -666.0  1.000000
# 5      DOID:0060072     -666.0  1.000000
# ...             ...        ...       ...
# 18140    DOID:12308     -666.0  1.000000
# 18141     DOID:3803     -666.0  1.000000
# 18142     DOID:2739     -666.0  1.000000
# 18143    DOID:13372     -666.0  1.000000
# 18144     DOID:2345     -666.0  1.000000
#
# [18144 rows x 7 columns]

# %%
        # ('CTD Gene-Disease Associations', 'ctddisease'),
        # ('GEO Signatures of Differentially Expressed Genes for Diseases', 'geodisease'),
        # ('HPO Gene-Disease Associations', 'hpo'),
        
        # ('GWASdb SNP-Disease Associations', 'gwasdbdisease'),
        # ('PhosphoSitePlus Phosphosite-Disease Associations', 'phosphositeplusdisease'),
        # ('DISEASES Text-mining Gene-Disease Assocation Evidence Scores', 'jensendiseasetextmining'),

# %%
https://civicdb.org/downloads/nightly/nightly-civic_accepted.vcf
